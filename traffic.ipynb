# %%
from glob import glob

img_list = glob('/home/gwon/ws/ml/yolov5/Traffic/images/*.png')
label_list = glob('/home/gwon/ws/ml/yolov5/Traffic/labels/*.txt')

# %%
print(len(img_list))
print(len(label_list))
# Out:
# 457
# 457

# %%
from sklearn.model_selection import train_test_split
train_img_list, val_img_list = train_test_split(img_list, test_size = 0.3,
random_state = 200)
print(len(train_img_list), len(val_img_list))
# Out:
# 319 138

# %%
with open('/home/gwon/ws/ml/yolov5/Traffic/train.txt','w') as f:
    f.write('\n'.join(train_img_list)+'\n')
with open('/home/gwon/ws/ml/yolov5/Traffic/val.txt', 'w') as f:
    f.write('\n'.join(val_img_list)+'\n')

# %%
# !pip install --upgrade opencv-python
# Out:
# ...
#   Using cached opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.2.0.34
#     Uninstalling opencv-python-4.2.0.34:
#       Successfully uninstalled opencv-python-4.2.0.34
# ...

# %%
# !python ../detect.py --weights /home/gwon/ws/ml/yolov5/runs/train/yolov5_cl56/weights/best.pt --source /home/gwon/ws/ml/yolov5/Traffic/hi.mp4 --img 640 --conf-thres 0.5
# Out:
# detect: weights=['/home/gwon/ws/ml/yolov5/runs/train/yolov5_cl56/weights/best.pt'], source=/home/gwon/ws/ml/yolov5/Traffic/hi.mp4, data=../data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-24-gf8539a6 Python-3.8.10 torch-1.11.0+cu113 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5947MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7031701 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/1051) /home/gwon/ws/ml/yolov5/Traffic/hi.mp4: 384x640 (no detections), 8.0ms
# video 1/1 (2/1051) /home/gwon/ws/ml/yolov5/Traffic/hi.mp4: 384x640 (no detections), 4.7ms
# ...
